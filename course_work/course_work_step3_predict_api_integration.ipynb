# %% [markdown]
# ### Проверка того, что наше api работает
# Перед началом необходимо собрать docker-образ и запустить контейнер
#
# 1. Следовать инструкциям https://github.com/djo1006/Machine-learning-in-business/blob/main/course_work/README.md
# 2. Далее уже запускать код ниже

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score,roc_curve
from urllib import request, parse

X_test = pd.read_csv("X_test.csv")
y_test = pd.read_csv("y_test.csv")

# %%
X_test.head(3)
# Out:
#    laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 0         2        18      4     3   1245         1        3     4       4
# 1         4        24      3     0    717         5        5     4       4
# 2         4        36      3     2   7678         3        4     2       2
#
#    buerge  wohnzeit  verm  alter  weitkred  wohn  bishkred  beruf  pers  \
# 0       1         2     3     33         3     2         1      3     2
# 1       1         4     3     54         3     2         2      3     2
# 2       1         4     3     40         3     2         2      3     2
#
#    telef  gastarb
# 0      1        2
# 1      2        2
# 2      2        2

# %%
import urllib.request
import json      


def get_prediction(body):

    myurl = "http://127.0.0.1:8180/predict"
    req = urllib.request.Request(myurl)
    req.add_header('Content-Type', 'application/json; charset=utf-8')
    jsondata = json.dumps(body)
    jsondataasbytes = jsondata.encode('utf-8')   # needs to be bytes
    req.add_header('Content-Length', len(jsondataasbytes))
    #print (jsondataasbytes)
    response = urllib.request.urlopen(req, jsondataasbytes)
    return json.loads(response.read())['predictions']

# %%
# %%time
# predictions = X_test[[
#     'laufkont', 'laufzeit', 'moral', 'verw', 'hoehe', 'sparkont', 'beszeit', 'rate',
#     'famges', 'buerge', 'wohnzeit', 'verm', 'alter', 'weitkred', 'wohn', 'bishkred',
#     'beruf', 'pers', 'telef', 'gastarb'
# ]].iloc[:100].apply(lambda x: get_prediction(x), 1)

#     laufkont,    laufzeit,    moral,    verw,    hoehe,    sparkont,    beszeit,    rate,
#     famges,    buerge,    wohnzeit,    verm,    alter,    weitkred,    wohn,    bishkred,
#     beruf,    pers,    telef,    gastarb = x
    
x = X_test.iloc[:100]
xx = x.to_dict('records')
# body = {'laufkont':x.laufkont, 'laufzeit':x.laufzeit, 'moral':x.moral, 'verw':x.verw, 'hoehe':x.hoehe, 'sparkont':x.sparkont,
#         'beszeit':x.beszeit, 'rate':x.rate, 'famges':x.famges, 'buerge':x.buerge, 'wohnzeit':x.wohnzeit, 'verm':x.verm, 
#         'alter':x.alter, 'weitkred':x.weitkred, 'wohn':x.wohn, 'bishkred':x.bishkred, 'beruf':x.beruf, 'pers':x.pers, 
#         'telef':x.telef, 'gastarb':x.gastarb} 


# get_prediction(xx)
# Out:
# CPU times: user 1.2 ms, sys: 977 µs, total: 2.18 ms
# Wall time: 2.1 ms
